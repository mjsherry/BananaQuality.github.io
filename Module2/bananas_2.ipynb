# %%
import pandas as pd
data = pd.read_csv('/Users/mikaelasherry/790/Module2/banana_quality.csv')

# %%
data = data.head(4000)

data
# Out:
#           Size    Weight  Sweetness  Softness  HarvestTime  Ripeness  \
# 0    -1.924968  0.468078   3.077832 -1.472177     0.294799  2.435570
# 1    -2.409751  0.486870   0.346921 -2.495099    -0.892213  2.067549
# 2    -0.357607  1.483176   1.568452 -2.645145    -0.647267  3.090643
# 3    -0.868524  1.566201   1.889605 -1.273761    -1.006278  1.873001
# 4     0.651825  1.319199  -0.022459 -1.209709    -1.430692  1.078345
# ...        ...       ...        ...       ...          ...       ...
# 3995 -3.629499 -3.874014  -0.984224 -0.918895    -1.216325  2.559522
# 3996 -1.374998 -2.172096  -2.852536 -2.205632    -1.066416  2.060665
# 3997 -2.827697 -3.324280  -0.868479 -3.914481    -0.376315  0.975730
# 3998 -1.099613 -1.419108  -0.930635 -2.288164    -2.224670  1.426270
# 3999  0.861932 -2.400732  -1.602941 -0.741475    -0.118077  2.644173
#
#        Acidity Quality
# 0     0.271290    Good
# 1     0.307325    Good
# 2     1.427322    Good
# 3     0.477862    Good
# ...

# %%
import altair as alt

# %%
alt.Chart(data).mark_bar().encode(
    x = alt.X('HarvestTime', title='Harvest Time'),
    y = "Sweetness",
    color = alt.Color('Quality', scale=alt.Scale(domain=['Bad', 'Good'], range=['red', 'green']))
).properties(
    title='Harvest Time vs. Sweetness'
    
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_circle().encode(
    x = "HarvestTime",
    y = "Sweetness",
    color="Quality"
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_circle().encode(
    x = "HarvestTime",
    y = "Ripeness",
    color="Quality"
)
# Out:
# alt.Chart(...)

# %%
data2 = data.tail(50)

data2
# Out:
#           Size    Weight  Sweetness  Softness  HarvestTime  Ripeness  \
# 3950  0.024276 -1.942753  -2.034682 -3.080297    -0.719400  2.636582
# 3951 -2.585995 -2.139504  -2.739707 -1.850548     0.366089  0.829329
# 3952 -4.625650  0.087904  -1.374429 -1.678209    -4.469970  0.086613
# 3953 -2.190372 -1.172197   0.710222 -0.714403    -3.024723  1.307468
# 3954 -0.176225 -0.826171  -0.982308  0.095432    -0.500472  1.959162
# 3955 -1.136977  0.387757  -2.121323 -0.424439     0.523804  0.912028
# 3956 -0.086140 -0.548724  -4.093402 -1.131514     0.569422  2.713413
# 3957 -5.509335  0.572964  -2.237597  0.077733    -3.919378  0.220734
# 3958 -1.839883  0.343031  -1.532489 -1.174580    -2.664222  0.801581
# 3959 -1.124761 -2.953856  -1.683391 -1.412037    -1.580336  2.329621
# 3960 -1.996892 -1.332251  -1.095289 -2.832679    -3.059323 -0.618737
# 3961  4.456726 -4.639701  -2.033198 -3.461103     0.987015  4.144379
# 3962 -2.823662  2.624271  -1.751715 -0.533659    -5.099486 -1.206701
# ...

# %%
alt.Chart(data2).mark_line().encode(
    x = "HarvestTime",
    y = "Ripeness",
    color="Quality"
)
# Out:
# alt.Chart(...)
